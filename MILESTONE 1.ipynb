# %%
import cv2
import mediapipe as mp
import numpy as np

print("OpenCV version:", cv2.__version__)
print("MediaPipe version:", mp.__version__)
print("NumPy version:", np.__version__)
# Out:
# OpenCV version: 4.11.0
# MediaPipe version: 0.10.21
# NumPy version: 1.26.4

# %%
import cv2, mediapipe as mp, numpy as np, matplotlib.pyplot as plt
print(cv2.__version__, mp.__version__, np.__version__)
# Out:
# 4.11.0 0.10.21 1.26.4

# %%
import cv2
import mediapipe as mp
import numpy as np
import matplotlib.pyplot as plt

print("python:", __import__('sys').version.split()[0])
print("numpy:", np.__version__)
print("opencv:", cv2.__version__)
print("mediapipe:", mp.__version__)

# Quick webcam test (press 'q' to quit)
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Cannot open camera")
else:
    ret, frame = cap.read()
    if ret:
        plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
        plt.title('Webcam frame (captured)')
        plt.axis('off')
    cap.release()
# Out:
# python: 3.10.19
# numpy: 1.26.4
# opencv: 4.11.0
# mediapipe: 0.10.21

# %%
import cv2
from matplotlib import pyplot as plt

# Use the real location of your file
img = cv2.imread(r"C:\Users\shrey\Downloads\butterfly.jpg", 0)

if img is None:
    print("⚠️ Could not load image – check the file name or path.")
else:
    # For a grayscale image, convert GRAY → RGB so matplotlib can show it
    img_rgb = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
    plt.imshow(img_rgb)
    plt.title('Loaded Image with OpenCV')
    plt.axis('off')
    plt.show()

# %%
import cv2
from matplotlib import pyplot as plt
import os

print("Current working directory:", os.getcwd())
# Out:
# Current working directory: C:\Users\shrey

# %%
import os
print("Current working directory:", os.getcwd())
print("Files in this folder:", os.listdir())
# Out:
# Current working directory: C:\Users\shrey\Desktop\CSCorner
# Files in this folder: []

# %%
import cv2
from matplotlib import pyplot as plt

# Use the real location of your file
img = cv2.imread(r"C:\Users\shrey\Downloads\butterfly.jpg", 0)

if img is None:
    print("⚠️ Could not load image – check the file name or path.")
else:
    # For a grayscale image, convert GRAY → RGB so matplotlib can show it
    img_rgb = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
    plt.imshow(img_rgb)
    plt.title('Loaded Image with OpenCV')
    plt.axis('off')
    plt.show()

# %%
print(img.shape)
print(img.size)
print(img.dtype)
# Out:
# (196, 258)
# 50568
# uint8

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap='gray')
plt.title('Grayscale Image')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       2 plt.imshow(gray, cmap='gray')
#       3 plt.title('Grayscale Image')
#
# error: OpenCV(4.11.0) d:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.simd_helpers.hpp:92: error: (-15:Bad number of channels) in function '__cdecl cv::impl::`anonymous-namespace'::CvtHelper<struct cv::impl::`anonymous namespace'::Set<3,4,-1>,struct cv::impl::A0x34dd5b3e::Set<1,-1,-1>,struct cv::impl::A0x34dd5b3e::Set<0,2,5>,4>::CvtHelper(const class cv::_InputArray &,const class cv::_OutputArray &,int)'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1

# %%
# Resize
resized = cv2.resize(img, (300, 200))
plt.imshow(resized)
#plt.imshow(img)
plt.title('Loaded Image with OpenCV')
plt.axis('off')
plt.show()
print(resized.shape)
# Out:
# (200, 300)

# %%
# Rotate (90° clockwise)
rotated = cv2.rotate(img, cv2.ROTATE_90_COUNTERCLOCKWISE)
plt.imshow(rotated)
#plt.imshow(img)
plt.title('Loaded Image with OpenCV')
plt.axis('off')
plt.show()

# %%
# Flip (0: vertical, 1: horizontal)
flipped = cv2.flip(img, 0)
plt.imshow(flipped)
#plt.imshow(img)
plt.title('Loaded Image with OpenCV')
plt.axis('off')
plt.show()

# %%
blur = cv2.GaussianBlur(img, (7, 7), 0)
plt.imshow(blur)
#plt.imshow(img)
plt.title('Image with Blur')
plt.axis('off')
plt.show()

# %%
edges = cv2.Canny(img, 100, 200)
plt.imshow(edges)
#plt.imshow(img)
plt.title('Image with edges')
plt.axis('off')
plt.show()

# %%
import cv2
from matplotlib import pyplot as plt

img = cv2.imread('butterfly.jpg', 1)  # Load color image

if img is None:
    print("⚠️ Image not found. Please check your file path.")
else:
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
    ret, thresh = cv2.threshold(img_gray, 127, 255, cv2.THRESH_BINARY)  # Thresholding
    
    plt.imshow(thresh, cmap='gray')  # Show binary image in grayscale colormap
    plt.title('Thresholded Image')
    plt.axis('on')
    plt.show()
# Out:
# ⚠️ Image not found. Please check your file path.

# %%
import os
print("Current directory:", os.getcwd())
print("Files here:", os.listdir())
# Out:
# Current directory: C:\Users\shrey\Desktop\CSCorner
# Files here: []

# %%
import cv2
from matplotlib import pyplot as plt

img = cv2.imread('butterfly.jpg', 1)  # Load color image

if img is None:
    print("⚠️ Image not found. Please check your file path.")
else:
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
    ret, thresh = cv2.threshold(img_gray, 127, 255, cv2.THRESH_BINARY)  # Thresholding
    
    plt.imshow(thresh, cmap='gray')  # Show binary image in grayscale colormap
    plt.title('Thresholded Image')
    plt.axis('on')
    plt.show()

# %%
canvas = img.copy()
cv2.rectangle(canvas, (50, 50), (200, 200), (255, 0, 0), 3)
cv2.circle(canvas, (300, 150), 50, (0, 255, 0), -1)
cv2.putText(canvas, 'OpenCV Demo', (50, 300),
cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2)
plt.imshow(canvas)
#plt.imshow(img)
plt.title('Loaded Image with Text,circle,rectangle')
plt.axis('on')
plt.show()

# %%
import cv2
cap = cv2.VideoCapture(0)  # 0 = default camera index
if not cap.isOpened():
    raise IOError("Cannot open webcam")
while True:
    ret, frame = cap.read()
    if not ret:
        break
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)  # demonstration
    cv2.imshow('Webcam (press q to quit)', gray)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
print(ret)
# Out:
# True

# %%
print(frame)
# Out:
# [[[ 49  80  89]
#   [ 50  81  90]
#   [ 49  81  91]
#   ...
#   [121 146 145]
#   [121 148 146]
#   [120 147 144]]
#
#  [[ 49  80  88]
#   [ 50  81  89]
#   [ 50  82  91]
#   ...
#   [124 148 147]
#   [122 148 146]
#   [119 146 143]]
#
#  [[ 49  81  87]
#   [ 50  82  88]
#   [ 50  82  90]
#   ...
#   [126 149 148]
#   [123 147 145]
#   [119 145 142]]
#
#  ...
#
#  [[ 24  35  43]
#   [ 28  39  47]
#   [ 35  45  53]
#   ...
#   [ 91 104 119]
#   [ 92 105 120]
#   [ 93 106 120]]
#
#  [[ 31  41  48]
#   [ 34  44  51]
#   [ 36  45  51]
#   ...
#   [ 90 102 121]
#   [ 92 103 122]
#   [ 94 103 122]]
#
#  [[ 27  37  44]
#   [ 31  40  46]
#   [ 38  47  51]
#   ...
#   [ 90 100 121]
#   [ 92 101 122]
#   [ 93 101 123]]]

# %%
cv2.imshow('frame',frame)

# %%
import cv2
import time

# Step 1: Open webcam (0 = default camera)
cap = cv2.VideoCapture(0)

# Step 2: Check if webcam is opened correctly
if not cap.isOpened():
    print("Error: Could not open webcam")
    exit()

# Step 3: Variables for FPS calculation
prev_time = 0

while True:
    # Step 4: Read one frame from the webcam
    ret, frame = cap.read()

    # If frame not captured correctly, break the loop
    if not ret:
        print("Failed to capture frame")
        break

    # Step 5: Calculate Frames Per Second (FPS)
    current_time = time.time()
    fps = 1 / (current_time - prev_time) if prev_time else 0
    prev_time = current_time

    # Step 6: Display FPS on the video frame
    cv2.putText(frame, f'FPS: {int(fps)}', (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

    # Step 7: Display the video frame in a window
    cv2.imshow("Video Frame", frame)

    # Step 8: Exit when 'q' key is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Step 9: Release resources
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import time
import os

# Step 1: Create a folder to save captured images
save_folder = "saved_frames"
os.makedirs(save_folder, exist_ok=True)

# Step 2: Open the webcam (0 = default camera)
cap = cv2.VideoCapture(0)

# Step 3: Check if the webcam opened successfully
if not cap.isOpened():
    print("Error: Could not open webcam")
    exit()

# Step 4: Variables for FPS calculation and frame count
prev_time = 0
frame_count = 0

# Step 5: How often to save frames (e.g., every 10th frame)
save_interval = 10  # Change this to 1 to save every frame

print("Press 'q' to quit capturing video...")

while True:
    # Step 6: Read a frame from the camera
    ret, frame = cap.read()

    if not ret:
        print("Error: Failed to capture frame")
        break

    # Step 7: Calculate FPS
    current_time = time.time()
    fps = 1 / (current_time - prev_time) if prev_time else 0
    prev_time = current_time

    # Step 8: Display FPS on the frame
    cv2.putText(frame, f'FPS: {int(fps)}', (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

    # Step 9: Display the frame in a window
    cv2.imshow("Video Frame", frame)

    # Step 10: Save every Nth frame as an image file
    frame_count += 1
    if frame_count % save_interval == 0:
        timestamp = time.strftime("%Y%m%d_%H%M%S")
        filename = os.path.join(save_folder, f"frame_{timestamp}_{frame_count}.jpg")
        cv2.imwrite(filename, frame)
        print(f"Saved: {filename}")

    # Step 11: Exit on pressing 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Step 12: Release camera and close windows
cap.release()
cv2.destroyAllWindows()

print("\nVideo capture ended.")
print(f"Images saved in folder: '{os.path.abspath(save_folder)}'")
# Out:
# Press 'q' to quit capturing video...
# Saved: saved_frames\frame_20251023_202910_10.jpg
# Saved: saved_frames\frame_20251023_202910_20.jpg
# Saved: saved_frames\frame_20251023_202911_30.jpg
# Saved: saved_frames\frame_20251023_202911_40.jpg
# Saved: saved_frames\frame_20251023_202911_50.jpg
# Saved: saved_frames\frame_20251023_202912_60.jpg
# Saved: saved_frames\frame_20251023_202912_70.jpg
# Saved: saved_frames\frame_20251023_202912_80.jpg
# Saved: saved_frames\frame_20251023_202913_90.jpg
# Saved: saved_frames\frame_20251023_202913_100.jpg
# Saved: saved_frames\frame_20251023_202913_110.jpg
# Saved: saved_frames\frame_20251023_202914_120.jpg
# Saved: saved_frames\frame_20251023_202914_130.jpg
# Saved: saved_frames\frame_20251023_202914_140.jpg
# Saved: saved_frames\frame_20251023_202915_150.jpg
# Saved: saved_frames\frame_20251023_202915_160.jpg
# Saved: saved_frames\frame_20251023_202915_170.jpg
# Saved: saved_frames\frame_20251023_202916_180.jpg
# ...

# %%
import cv2
import numpy as np

# Step 1: Create a blank image (black background)
img = np.zeros((500, 700, 3), dtype=np.uint8)

# Step 2: Draw a rectangle
# cv2.rectangle(image, top_left_corner, bottom_right_corner, color, thickness)
cv2.rectangle(img, (50, 50), (250, 200), (0, 255, 0), 3)

# Step 3: Draw a filled rectangle
cv2.rectangle(img, (300, 50), (500, 200), (255, 0, 0), -1)  # -1 = filled

# Step 4: Draw a circle
# cv2.circle(image, center, radius, color, thickness)
cv2.circle(img, (150, 350), 60, (0, 0, 255), 5)

# Step 5: Draw a filled circle
cv2.circle(img, (400, 350), 60, (0, 255, 255), -1)

# Step 6: Draw a line
# cv2.line(image, start_point, end_point, color, thickness)
cv2.line(img, (50, 400), (600, 400), (255, 255, 255), 2)

# Step 7: Add text
# cv2.putText(image, text, position, font, scale, color, thickness)
cv2.putText(img, "OpenCV Drawing Demo", (100, 470),
            cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

# Step 8: Display the image
cv2.imshow("Drawing on Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Draw rectangle and text on video frame
    cv2.rectangle(frame, (100, 100), (300, 300), (0, 255, 0), 2)
    cv2.putText(frame, "Live Annotation", (110, 90),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 255), 2)

    cv2.imshow("Live Video Annotation", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
from matplotlib import pyplot as plt
# Load an image (make sure you have an image file in the same folder)
img = cv2.imread('butterfly.jpg',1)  # replace with your image name
# Convert BGR (OpenCV default) to RGB for Matplotlib display
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(img_rgb, 127, 255, cv2.THRESH_BINARY)
# Display
plt.imshow(thresh)
#plt.imshow(img)
plt.title('Loaded Image with OpenCV')
plt.axis('on')
plt.show()
#ret, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[5], line 6
#       4 img = cv2.imread('butterfly.jpg',1)  # replace with your image name
#       5 # Convert BGR (OpenCV default) to RGB for Matplotlib display
# ----> 6 img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       7 ret, thresh = cv2.threshold(img_rgb, 127, 255, cv2.THRESH_BINARY)
#       8 # Display
#
# error: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
